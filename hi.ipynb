# %% [markdown]
# ---
# layout: single
# author_profile: true
# permalink: /cv/
# title: Curriculum Vitae
# tags: [cv, academic, resume]
# modified: 2025-10-20
# comments: false
# ---
#
# # **Helia Shams Zadeh Amiri**
#
# **Tehran, Iran**
# 📧 [shamszadehhelia@gmail.com](mailto:shamszadehhelia@gmail.com) 📞 +98 933 318 3898 🌐 [linkedin.com/in/helia-shamszadeh](https://www.linkedin.com/in/helia-shamszadeh)
#
# ---
#
# ## 🧠 **Education**
#
# | **Period** | **Institution & Degree** | **Details** |
# |:------------|:--------------------------|:-------------|
# | **2021 – 2025** | **B.Sc. in Computer Engineering**, Iran University of Science and Technology (IUST), Tehran | *CGPA:* 18.86 / 20 |
# | **2018 – 2021** | **High School Diploma**, National Organization for Development of Exceptional Talents (Sampad – Farzanegan 1), Tehran | *CGPA:* 19.93 / 20 |
#
# ---
#
# ## 🔬 **Research & Academic Experience**
#
# | **Period** | **Position & Institution** | **Summary of Responsibilities** |
# |:------------|:---------------------------|:--------------------------------|
# | **Jul 2025 – Present** | **Data Scientist**, Ferrum Capital (Baku, Remote) | ‣ Preprocessed large-scale financial data for credit scoring.<br>‣ Built ML models to evaluate credit risk.<br>‣ Integrated models into production pipelines to enhance prediction accuracy. |
# | **Jul 2024 – Sept 2024** | **Research Assistant (Intern)**, Data Mining Laboratory – IUST | *Supervisor: Dr. Behrouz Minaei-Bidgoli*<br>‣ Reviewed and implemented findings from 20+ scholarly papers in image retrieval and data mining.<br>‣ Improved data workflows and retrieval accuracy via Python scripting. |
# | **2023 – 2025 (Teaching Assistant)** | *Iran University of Science and Technology (IUST)* | **Courses:**<br>– Fundamentals of Computer Vision (Dr. MohammadReza Mohammadi)<br>– Operating Systems (Dr. Reza Entezari-Maleki)<br>– Theory of Languages & Automata (Dr. Reza Entezari-Maleki)<br>– Data Structures (Dr. Hossein Rahmani)<br>– Advanced Programming (Dr. Sauleh Eetemadi & Dr. Marzieh Maleki-Majd)<br>– Product Owner in Software Engineering and Systems Analysis (Dr. Amir Mohammadzadeh Lajevardi, Dr. Mehrdad Ashtiani) |
#
# ---
#
# ## 💻 **Selected Projects**
#
# | **Year** | **Project Title** | **Description** |
# |:----------|:------------------|:----------------|
# | **2025 (Summer)** | **Transforming Text into Structured Knowledge: A Frame-Semantics and RDF-based Approach** | *Undergraduate Thesis* – Developed a semantic extraction pipeline using SRL, entity linking, and RDF conversion. Integrated evaluation via LLM-as-Judge.<br>🔗 [GitHub Repository](#) |
# | **2025 (Winter)** | **ENIAC Project – System Analysis and Design / Software Engineering** | Designed a full-stack web app for a psychological clinic (Django + React). Features appointment booking and AI chatbot.<br>🔗 [GitHub Repository](#) |
# | **2025 (Winter)** | **Movie Revenue Prediction & Exploratory Data Analysis** | Created ML models and visual analytics for box-office prediction using Python (Pandas, Scikit-Learn, Matplotlib). |
# | **2025 (Winter)** | **Copy Number Variation (CNV) Analysis in Human Genome** | *Fundamentals of Bioinformatics Course Project* – Visualized CNV changes using bioinformatics tools. |
# | **2024 (Spring)** | **Anti-Spoofing in Face Recognition** | Implemented real-time spoof detection system integrated with recognition pipelines. |
# | **2024 (Spring)** | **Object Detection with YOLO** | Built a YOLO-based detector for identifying books in video frames. |
# | **2024 (Winter)** | **Sentiment Analysis of Tweets** | Developed sentiment classifier for positive/neutral/negative tweets. |
# | **2024 (Winter)** | **AI-based Game Agents** | Designed intelligent agents for *Flappy Bird*, *2048*, *Sudoku*, and *Water Sort*. |
# | **2021 (Fall)** | **BorBook Project** | Created a Django-based digital book management system. |
#
# ---
#
# ## ⚙️ **Technical Skills**
#
# | **Category** | **Competencies** |
# |:--------------|:-----------------|
# | **Programming Languages** | Python · C# · Go · SQL · JavaScript |
# | **Frameworks & Libraries** | Django · ReactJS · NumPy · Pandas · PyTorch · TensorFlow · Keras · OpenCV |
# | **Languages** | Persian (Native) · English (C1, IELTS 8.0) · German (A2) · French (A1) |
# | **Core Competencies** | Data Analysis · Machine Learning · Software Design · Problem Solving · Research Writing · Collaboration |
#
# ---
#
# ## 🎓 **Certificates**
#
# | **Title** | **Institution / Platform** | **Details** |
# |:------------|:----------------------------|:-------------|
# | *Supervised Machine Learning: Regression and Classification* | Coursera | Certificate of Completion |
# | *Back-End Development with Golang Bootcamp* | Iran University of Science and Technology | In-person Bootcamp |
# | *IELTS (Academic)* | British Council | Overall Band 8.0 (L 9.0 · R 8.0 · W 7.0 · S 7.5) – Valid until Nov 2026 |
#
# ---
#
# ## 🏅 **Honors & Awards**
#
# | **Year** | **Recognition** |
# |:-----------|:----------------|
# | **2025** | Ranked among the **Top 5%** of Computer Engineering students (IUST) |
# | **2021** | Placed **540 / 126,740** in the Iranian National University Entrance Exam (Konkur) |
#
# ---
#
# ## 📄 **References**
#
# Available upon request.
